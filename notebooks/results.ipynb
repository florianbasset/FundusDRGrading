# %%
import wandb
import pandas as pd
import numpy as np
import bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, Whisker
from bokeh.transform import factor_cmap, jitter
from bokeh.layouts import gridplot

# %%
api = wandb.Api()
runs = api.runs("hmr24/FundusDRGrading-src_fundusClassif_scripts")

important_keys = ['lr', 'ema', 'swa', 'mixup', 'preprocessing', 'as_regression']
list_configs = []
for i, r in enumerate(runs):
    kappa = r.summary_metrics.get("Validation Quadratic Kappa", None)
    if kappa is None:
        continue
    config = {k: v for k, v in r.config.items() if k in important_keys}
    config['name'] = r.name
    config['kappa'] = kappa
    
    list_configs.append(config)
    
    
df = pd.DataFrame(list_configs)

df['ema'] = df['ema'].map({1: 'EMA', 0: 'No EMA'})
df['swa'] = df['swa'].map({1: 'SWA', 0: 'No SWA'})
df['mixup'] = df['mixup'].map({1: 'Mixup', 0: 'No Mixup'})
df['as_regression'] = df['as_regression'].map({1: 'Regression', 0: 'Classification'})
df
# Out:
#           lr     ema     swa     mixup   as_regression        preprocessing  \
# 0   0.000034  No EMA     SWA     Mixup  Classification          autobalance
# 1   0.000025  No EMA     SWA  No Mixup  Classification                seoud
# 2   0.000049     EMA  No SWA  No Mixup      Regression                sarki
# 3   0.000025     EMA     SWA  No Mixup  Classification            clahe_rgb
# 4   0.000041     EMA     SWA     Mixup  Classification            clahe_lab
# 5   0.000026     EMA     SWA     Mixup  Classification                sarki
# 6   0.000039     EMA  No SWA     Mixup  Classification            clahe_lab
# 7   0.000017     EMA  No SWA  No Mixup      Regression            clahe_rgb
# 8   0.000028     EMA     SWA     Mixup  Classification               absent
# 9   0.000037     EMA     SWA     Mixup  Classification            clahe_lab
# 10  0.000038  No EMA     SWA     Mixup  Classification               absent
# 11  0.000045     EMA     SWA  No Mixup      Regression               absent
# 12  0.000041     EMA  No SWA     Mixup  Classification          autobalance
# 13  0.000019     EMA     SWA  No Mixup      Regression                seoud
# 14  0.000045     EMA  No SWA     Mixup  Classification  clahe_max_green_gsc
# 15  0.000034  No EMA  No SWA  No Mixup  Classification            clahe_rgb
# 16  0.000014     EMA     SWA  No Mixup      Regression                seoud
# 17  0.000031  No EMA  No SWA  No Mixup  Classification            clahe_lab
# 18  0.000032     EMA  No SWA     Mixup  Classification            clahe_lab
# 19  0.000041     EMA  No SWA  No Mixup  Classification                seoud
# 20  0.000038  No EMA     SWA  No Mixup      Regression                sarki
# 21  0.000034     EMA  No SWA  No Mixup      Regression            clahe_lab
# 22  0.000031     EMA  No SWA  No Mixup  Classification          autobalance
# 23  0.000026  No EMA  No SWA  No Mixup      Regression               absent
# 24  0.000034  No EMA  No SWA     Mixup  Classification                seoud
# 25  0.000029  No EMA     SWA  No Mixup  Classification            clahe_rgb
# 26  0.000030  No EMA  No SWA  No Mixup  Classification          autobalance
# 27  0.000037     EMA  No SWA  No Mixup  Classification            clahe_rgb
# 28  0.000035     EMA     SWA  No Mixup  Classification            clahe_lab
# 29  0.000029     EMA     SWA     Mixup  Classification                sarki
# 30  0.000031  No EMA  No SWA  No Mixup      Regression            clahe_rgb
# 31  0.000029  No EMA  No SWA     Mixup  Classification                sarki
# 32  0.000030     EMA     SWA  No Mixup      Regression                sarki
# 33  0.000035  No EMA  No SWA  No Mixup      Regression            clahe_lab
# 34  0.000036     EMA  No SWA  No Mixup      Regression               absent
# 35  0.000029  No EMA  No SWA  No Mixup  Classification               absent
# 36  0.000048     EMA  No SWA  No Mixup  Classification            clahe_rgb
# 37  0.000038  No EMA  No SWA  No Mixup      Regression                sarki
# 38  0.000028     EMA  No SWA  No Mixup  Classification            clahe_rgb
# 39  0.000034  No EMA     SWA  No Mixup      Regression                seoud
# 40  0.000030  No EMA  No SWA  No Mixup      Regression            clahe_rgb
# 41  0.000046  No EMA  No SWA  No Mixup      Regression            clahe_lab
#
#                   name     kappa kappa_ddr kappa_eyepacs kappa_idrid
# 0        fiery-sweep-1  0.931952      None          None        None
# 1      logical-sweep-2  0.943428      None          None        None
# 2         deft-sweep-4  0.749284      None          None        None
# 3        brisk-sweep-5  0.765770      None          None        None
# 4   effortless-sweep-6  0.705447      None          None        None
# 5      skilled-sweep-7  0.626413      None          None        None
# 6    resilient-sweep-8  0.687334      None          None        None
# 7   glamorous-sweep-11  0.703558      None          None        None
# 8        avid-sweep-12  0.721227      None          None        None
# 9       solar-sweep-13  0.704996      None          None        None
# 10   fearless-sweep-16  0.947329      None          None        None
# 11      solar-sweep-18  0.902107      None          None        None
# 12  chocolate-sweep-19  0.718950      None          None        None
# 13      royal-sweep-20  0.670351      None          None        None
# 14   ethereal-sweep-21  0.709278      None          None        None
# 15     dainty-sweep-22  0.956727      None          None        None
# 16     copper-sweep-23  0.653102      None          None        None
# 17    exalted-sweep-25  0.959145      None          None        None
# 18     fallen-sweep-27  0.682522      None          None        None
# 19   graceful-sweep-28  0.765450      None          None        None
# 20      fancy-sweep-29  0.748515      None          None        None
# 21      denim-sweep-30  0.692979      None          None        None
# 22    playful-sweep-31  0.739880      None          None        None
# 23     spring-sweep-32  0.716006      None          None        None
# 24       rosy-sweep-34  0.685072      None          None        None
# 25    gallant-sweep-35  0.958469      None          None        None
# 26       fast-sweep-37  0.862673      None          None        None
# 27       soft-sweep-38  0.741834      None          None        None
# 28     wobbly-sweep-40  0.957151      None          None        None
# 29   blooming-sweep-42  0.567482      None          None        None
# 30     iconic-sweep-43  0.897591      None          None        None
# 31   faithful-sweep-44  0.708022      None          None        None
# 32    valiant-sweep-45  0.674597      None          None        None
# 33      light-sweep-46  0.904181      None          None        None
# 34    devoted-sweep-47  0.673747      None          None        None
# 35      usual-sweep-48  0.919654      None          None        None
# 36       firm-sweep-49  0.958879      None          None        None
# 37      light-sweep-50  0.714634      None          None        None
# 38      misty-sweep-51  0.917238      None          None        None
# 39     cosmic-sweep-53  0.760851      None          None        None
# 40     upbeat-sweep-54  0.897350      None          None        None
# 41     driven-sweep-55  0.912408      None          None        None

# %%
import statsmodels
import statsmodels.api as sm
import statsmodels.api
import statsmodels.formula
import statsmodels.formula.api

def map_pvalue_to_star(p):
    sym = "⋆"
    if p < 0.001:
        return sym*3
    if p < 0.01:
        return sym*2
    if p < 0.05:
        return sym
    return ""

def get_graph(df, key):
    df.sort_values(key, inplace=True)
    result = statsmodels.formula.api.ols(f'kappa ~ {key}', data=df).fit()
    table = statsmodels.api.stats.anova_lm(result)
    stats_test = table.loc[key, 'PR(>F)']
    pvalue = stats_test.round(3)
    #pvalue_star = map_pvalue_to_star(stats_test)
    g = df.groupby(key)
    groups = g.groups
    order_of_groups = list(groups.keys())
    print("Ordre des groupes :", order_of_groups)

    upper = g.kappa.quantile(0.90)
    lower = g.kappa.quantile(0.10)

    datasource = ColumnDataSource(df)
    output_notebook()
    
    classes = list(df[key].unique())
    classes.sort()
    print(classes)

    #inverser l'ordre des classes pour que le graphique soit plus lisible en fonction de la legende
    if key == 'swa' or key == 'as_regression':
        classes = classes[::-1]

    p = figure(height=500, x_range=classes, title=f"Kappa by {key.upper()}", tools='')

    source = ColumnDataSource(data=dict(base=classes,upper=upper, lower=lower, middle=g.kappa.mean()))

    error = Whisker(base="base", upper="upper", lower="lower", source=source,
                    level="annotation", line_width=2, line_alpha=.5)
    middle = Whisker(base="base", upper="middle", lower="middle", source=source, line_width=4, line_alpha=0.5)
    
    middle.upper_head.size=20
    middle.lower_head.size=20
    
    p.add_layout(middle)
    
    error.upper_head.size=10
    error.lower_head.size=10
    #p.text(x=1, y=.965, text=[pvalue_star], text_align='center', text_baseline='middle', text_font_size='12pt')
    #p.text(x=1, y=.95, text=[f'p = {pvalue}'], text_align='center', text_baseline='middle', text_font_size='12pt')
    p.add_layout(error)

    p.scatter(jitter(key, 0.1, range=p.x_range), y='kappa', 
            source=datasource, 
            size=10, 
            line_color="white",
            color=factor_cmap(key, "Light7", classes),
            alpha=0.8)
    return p


p_ema = get_graph(df, 'ema')
p_swa = get_graph(df, 'swa')
p_mixup = get_graph(df, 'mixup')
p_as_regression = get_graph(df, 'as_regression')

grid = gridplot([[p_ema, p_swa], [p_mixup, p_as_regression]])
show(grid)
# Out:
# Ordre des groupes : ['EMA', 'No EMA']
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="eb18c6a6-72fc-44e8-a837-2cf67be4becf">Loading BokehJS ...</span>
#     </div>
# ['EMA', 'No EMA']
# Ordre des groupes : ['No SWA', 'SWA']
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fdc0dc0e-4e1f-41ab-8eca-6985c89dca34">Loading BokehJS ...</span>
#     </div>
# ['No SWA', 'SWA']
# Ordre des groupes : ['Mixup', 'No Mixup']
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c4827b4c-3787-46b6-84a3-ae6a2eb89ae0">Loading BokehJS ...</span>
#     </div>
# ['Mixup', 'No Mixup']
# Ordre des groupes : ['Classification', 'Regression']
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="df405ead-9f6a-4036-bd9b-a9d3ec60fca4">Loading BokehJS ...</span>
#     </div>
# ['Classification', 'Regression']
#   <div id="cdde4929-4737-42eb-bd36-5b9054f672d5" data-root-id="p10005" style="display: contents;"></div>

# %%
p = get_graph(df, 'preprocessing')

show(p)
# Out:
# Ordre des groupes : ['absent', 'autobalance', 'clahe_lab', 'clahe_max_green_gsc', 'clahe_rgb', 'sarki', 'seoud']
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b0f2db4c-8914-4039-9c4b-d98c84c76661">Loading BokehJS ...</span>
#     </div>
# ['absent', 'autobalance', 'clahe_lab', 'clahe_max_green_gsc', 'clahe_rgb', 'sarki', 'seoud']
#   <div id="c1ddf6c5-23f5-4457-84dc-46949d856cd5" data-root-id="p10034" style="display: contents;"></div>

# %%
#ajout des bars pour chaque preprocessing 

from bokeh.models import ColumnDataSource, FactorRange
from bokeh.palettes import MediumContrast3
from bokeh.plotting import figure, show
from bokeh.transform import factor_cmap

preprocessing = ['absent', 'autobalance', 'clahe_lab', 'clahe_mgg', 'clahe_rgb','graham_meth1','graham_meth2', 'sarki', 'seoud']
databases_name = ['EYEPACS', 'IDRID', 'DDR']

data = {'preprocessing' : preprocessing,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 3, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

x = [ (fruit, year) for fruit in preprocessing for year in databases_name ]
counts = sum(zip(data['2015'], data['2016'], data['2017']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=350, title="Quadratic Kappa test on different preprocessing",
           toolbar_location=None, tools="",output_backend="svg")

p.vbar(x='x', top='counts', width=0.9, source=source, line_color="white",
       fill_color=factor_cmap('x', palette=MediumContrast3, factors=databases_name, start=1, end=2))

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('counts', 18), ('x', 27)
#   <div id="b82b8451-12ce-4b19-ba0a-142dc21aa06c" data-root-id="p10093" style="display: contents;"></div>
